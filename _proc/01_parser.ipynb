# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Parser)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L8){target="_blank" style="float:right; font-size:smaller"}
#
# ### Parser
#
# >      Parser (input)
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
#| echo: false
#| output: asis
show_doc(PRV)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### PRV
#
# >      PRV (v='', s=True, e='')
#
# *Initialize self.  See help(type(self)) for accurate signature.*

# %%
#| echo: false
#| output: asis
show_doc(char)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L39){target="_blank" style="float:right; font-size:smaller"}
#
# ### char
#
# >      char ()

# %%
assert char()(Parser("1")) == PRV('1')

# %%
#| echo: false
#| output: asis
show_doc(satisfy)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L50){target="_blank" style="float:right; font-size:smaller"}
#
# ### satisfy
#
# >      satisfy (parser, acceptor)

# %%
#| echo: false
#| output: asis
show_doc(ascii_letter)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L69){target="_blank" style="float:right; font-size:smaller"}
#
# ### ascii_letter
#
# >      ascii_letter ()

# %%
#| echo: false
#| output: asis
show_doc(digit)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L65){target="_blank" style="float:right; font-size:smaller"}
#
# ### digit
#
# >      digit ()

# %%
assert digit()(Parser("1")) == PRV('1')
assert digit()(Parser("a")) == PRV(s=False,e='satisfy failed')

# %%
assert ascii_letter()(Parser("1")) == PRV(s=False,e='satisfy failed')
assert ascii_letter()(Parser("a")) == PRV('a')

# %%
#| echo: false
#| output: asis
show_doc(many)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L75){target="_blank" style="float:right; font-size:smaller"}
#
# ### many
#
# >      many (parser)

# %%
assert many(digit())(Parser("123abc")) == PRV(['1','2','3'])
assert many(digit())(Parser("abc")) == PRV([])

# %%
#| echo: false
#| output: asis
show_doc(sequence)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L88){target="_blank" style="float:right; font-size:smaller"}
#
# ### sequence
#
# >      sequence (parsers)

# %%
assert sequence([digit(),digit(),digit()])(Parser("123")) == PRV(['1','2','3'])
assert sequence([digit(),ascii_letter(),digit()])(Parser("1a3")) == PRV(['1','a','3'])

# %%
#| echo: false
#| output: asis
show_doc(mapper)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L105){target="_blank" style="float:right; font-size:smaller"}
#
# ### mapper
#
# >      mapper (parser, funcs)

# %%
#| echo: false
#| output: asis
show_doc(accumulator)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L116){target="_blank" style="float:right; font-size:smaller"}
#
# ### accumulator
#
# >      accumulator (parser, acc)

# %%
#| echo: false
#| output: asis
show_doc(digits)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L128){target="_blank" style="float:right; font-size:smaller"}
#
# ### digits
#
# >      digits ()

# %%
assert digits()(Parser("123")) == PRV(['123'])
assert digits()(Parser("abc")) == PRV(s=False,e='sequence failed')

# %%
#| echo: false
#| output: asis
show_doc(integer)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L133){target="_blank" style="float:right; font-size:smaller"}
#
# ### integer
#
# >      integer ()

# %%
assert integer()(Parser("123")) == PRV([123])

# %%
#| echo: false
#| output: asis
show_doc(ws)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L137){target="_blank" style="float:right; font-size:smaller"}
#
# ### ws
#
# >      ws ()

# %%
#| echo: false
#| output: asis
show_doc(nl)
# Out:
# ---
#
# [source](https://github.com/Fflath/aoc2024/blob/main/aoc2024/core.py#L149){target="_blank" style="float:right; font-size:smaller"}
#
# ### nl
#
# >      nl ()
